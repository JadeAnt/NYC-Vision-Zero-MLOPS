# %% [markdown]
# ## Delete infrastructure with Terraform
#
# Since we provisioned our infrastructure with Terraform, we can also delete all the associated resources using Terraform.

# %%
# runs in Chameleon Jupyter environment
cd /work/NYC-Vision-Zero-MLOPS/tf/kvm

# %%
# runs in Chameleon Jupyter environment
export PATH=/work/.local/bin:$PATH

# %%
# runs in Chameleon Jupyter environment
unset $(set | grep -o "^OS_[A-Za-z0-9_]*")

# %% [markdown]
# In the following cell, **replace `netID` with your actual net ID, and replace `id_rsa_chameleon` with the name of *your* personal key that you use to access Chameleon resources**.

# %%
# runs in Chameleon Jupyter environment
export TF_VAR_suffix=jja435
export TF_VAR_key=nyc-vision-zero

# %%
# runs in Chameleon Jupyter environment
terraform destroy -auto-approve
# Out:
# data.openstack_networking_secgroup_v2.allow_ssh: Reading...
# data.openstack_networking_secgroup_v2.allow_http_80: Reading...
# data.openstack_networking_secgroup_v2.allow_9001: Reading...
# data.openstack_networking_secgroup_v2.allow_8081: Reading...
# data.openstack_networking_secgroup_v2.allow_8080: Reading...
# data.openstack_networking_secgroup_v2.allow_9090: Reading...
# data.openstack_networking_secgroup_v2.allow_8000: Reading...
# data.openstack_networking_network_v2.sharednet2: Reading...
# data.openstack_networking_subnet_v2.sharednet2_subnet: Reading...
# openstack_networking_network_v2.private_net: Refreshing state... [id=63b29d27-ec7d-4470-ba29-2e808e78457b]
# data.openstack_networking_secgroup_v2.allow_9001: Read complete after 1s [id=ad2912c0-caa9-49e0-b431-b9b3953b91b3]
# data.openstack_networking_secgroup_v2.allow_8080: Read complete after 1s [id=e6eff5db-c96d-4e3d-be49-1ade281f4a7a]
# data.openstack_networking_secgroup_v2.allow_http_80: Read complete after 1s [id=5df2db36-79f9-4b9b-b6c9-1ece762d83fb]
# data.openstack_networking_subnet_v2.sharednet2_subnet: Read complete after 1s [id=00b8d316-7617-4da4-b6c0-b7dd1dd78cd4]
# data.openstack_networking_secgroup_v2.allow_9090: Read complete after 1s [id=d6736d54-d9a4-431c-a5b5-4d29dbcdee03]
# data.openstack_networking_secgroup_v2.allow_ssh: Read complete after 1s [id=47860acf-9269-4d26-84b1-363824f7e0a2]
# data.openstack_networking_secgroup_v2.allow_8081: Read complete after 1s [id=9806d71f-f0bd-4c5d-8c48-f32db3094575]
# data.openstack_networking_secgroup_v2.allow_8000: Read complete after 1s [id=17a6d962-cc23-4551-ac0b-08b098f451d2]
# data.openstack_networking_network_v2.sharednet2: Read complete after 1s [id=4ec616b2-79e1-4813-abca-f2ceb41e0a89]
# openstack_networking_port_v2.sharednet2_ports["node3"]: Refreshing state... [id=ce5fe7a6-e5d4-427f-a4f6-a3acbd47f78c]
# openstack_networking_port_v2.sharednet2_ports["node1"]: Refreshing state... [id=01ed38ea-8c3d-46ea-b70c-8e63c1d9e859]
# openstack_networking_port_v2.sharednet2_ports["node2"]: Refreshing state... [id=00ea009a-2581-435b-beab-db441abc7f8c]
# openstack_networking_subnet_v2.private_subnet: Refreshing state... [id=93285c03-eb3d-4633-8b5a-8d79235dc24f]
# openstack_networking_port_v2.private_net_ports["node1"]: Refreshing state... [id=c32dd38c-7f5d-45db-afdf-320c8df887e2]
# openstack_networking_port_v2.private_net_ports["node3"]: Refreshing state... [id=2ff4d392-02cd-4b7f-b8c2-5777324cb16e]
# openstack_networking_floatingip_v2.floating_ip: Refreshing state... [id=b3363574-5d0c-4d9d-b70e-cfb37fd8efef]
# openstack_networking_port_v2.private_net_ports["node2"]: Refreshing state... [id=ac46a797-0594-41bb-aae8-60fe6e599fd5]
# openstack_compute_instance_v2.nodes["node2"]: Refreshing state... [id=f4a623fd-f5df-48c7-acf2-018e7cbcf1ad]
# openstack_compute_instance_v2.nodes["node3"]: Refreshing state... [id=690a953b-e2f7-46a0-879b-b1bb25128a2d]
# openstack_compute_instance_v2.nodes["node1"]: Refreshing state... [id=be9dfc79-7899-4f34-9150-c615b616d341]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # openstack_compute_instance_v2.nodes["node1"] will be destroyed
#   - resource "openstack_compute_instance_v2" "nodes" {
#       - access_ip_v4        = "10.56.0.247" -> null
#       - all_metadata        = {} -> null
#       - all_tags            = [] -> null
#       - availability_zone   = "nova" -> null
#       - created             = "2025-04-29 22:23:34 +0000 UTC" -> null
#       - flavor_id           = "3" -> null
#       - flavor_name         = "m1.medium" -> null
#       - force_delete        = false -> null
#       - id                  = "be9dfc79-7899-4f34-9150-c615b616d341" -> null
#       - image_id            = "96d9c658-6540-4796-ae64-54d8ac6c45f8" -> null
#       - image_name          = "CC-Ubuntu24.04" -> null
#       - key_pair            = "nyc_vision_zero" -> null
#       - name                = "node1-mlops-jja435" -> null
#       - power_state         = "active" -> null
#       - region              = "KVM@TACC" -> null
#       - security_groups     = [
#           - "allow-8000",
#           - "allow-8080",
#           - "allow-8081",
#           - "allow-9001",
#           - "allow-9090",
#           - "allow-http-80",
#           - "allow-ssh",
#         ] -> null
#       - stop_before_destroy = false -> null
#       - tags                = [] -> null
#       - updated             = "2025-04-29 22:23:45 +0000 UTC" -> null
#       - user_data           = "9c5760b512f2c5e455c569071558564b33f86f49" -> null
#         # (1 unchanged attribute hidden)
#
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "10.56.0.247" -> null
#           - mac            = "fa:16:3e:5b:dd:f7" -> null
#           - name           = "sharednet2" -> null
#           - port           = "01ed38ea-8c3d-46ea-b70c-8e63c1d9e859" -> null
#           - uuid           = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#             # (2 unchanged attributes hidden)
#         }
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "192.168.1.11" -> null
#           - mac            = "fa:16:3e:8d:e5:74" -> null
#           - name           = "private-net-mlops-jja435" -> null
#           - port           = "c32dd38c-7f5d-45db-afdf-320c8df887e2" -> null
#           - uuid           = "63b29d27-ec7d-4470-ba29-2e808e78457b" -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_compute_instance_v2.nodes["node2"] will be destroyed
#   - resource "openstack_compute_instance_v2" "nodes" {
#       - access_ip_v4        = "10.56.0.223" -> null
#       - all_metadata        = {} -> null
#       - all_tags            = [] -> null
#       - availability_zone   = "nova" -> null
#       - created             = "2025-04-29 22:23:34 +0000 UTC" -> null
#       - flavor_id           = "3" -> null
#       - flavor_name         = "m1.medium" -> null
#       - force_delete        = false -> null
#       - id                  = "f4a623fd-f5df-48c7-acf2-018e7cbcf1ad" -> null
#       - image_id            = "96d9c658-6540-4796-ae64-54d8ac6c45f8" -> null
#       - image_name          = "CC-Ubuntu24.04" -> null
#       - key_pair            = "nyc_vision_zero" -> null
#       - name                = "node2-mlops-jja435" -> null
#       - power_state         = "active" -> null
#       - region              = "KVM@TACC" -> null
#       - security_groups     = [
#           - "allow-8000",
#           - "allow-8080",
#           - "allow-8081",
#           - "allow-9001",
#           - "allow-9090",
#           - "allow-http-80",
#           - "allow-ssh",
#         ] -> null
#       - stop_before_destroy = false -> null
#       - tags                = [] -> null
#       - updated             = "2025-04-29 22:23:46 +0000 UTC" -> null
#       - user_data           = "cfa319df9858687c6ebfa99c2d7757cf52129e16" -> null
#         # (1 unchanged attribute hidden)
#
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "10.56.0.223" -> null
#           - mac            = "fa:16:3e:e4:74:9b" -> null
#           - name           = "sharednet2" -> null
#           - port           = "00ea009a-2581-435b-beab-db441abc7f8c" -> null
#           - uuid           = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#             # (2 unchanged attributes hidden)
#         }
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "192.168.1.12" -> null
#           - mac            = "fa:16:3e:af:96:10" -> null
#           - name           = "private-net-mlops-jja435" -> null
#           - port           = "ac46a797-0594-41bb-aae8-60fe6e599fd5" -> null
#           - uuid           = "63b29d27-ec7d-4470-ba29-2e808e78457b" -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_compute_instance_v2.nodes["node3"] will be destroyed
#   - resource "openstack_compute_instance_v2" "nodes" {
#       - access_ip_v4        = "10.56.3.139" -> null
#       - all_metadata        = {} -> null
#       - all_tags            = [] -> null
#       - availability_zone   = "nova" -> null
#       - created             = "2025-04-29 22:24:51 +0000 UTC" -> null
#       - flavor_id           = "3" -> null
#       - flavor_name         = "m1.medium" -> null
#       - force_delete        = false -> null
#       - id                  = "690a953b-e2f7-46a0-879b-b1bb25128a2d" -> null
#       - image_id            = "96d9c658-6540-4796-ae64-54d8ac6c45f8" -> null
#       - image_name          = "CC-Ubuntu24.04" -> null
#       - key_pair            = "nyc_vision_zero" -> null
#       - name                = "node3-mlops-jja435" -> null
#       - power_state         = "active" -> null
#       - region              = "KVM@TACC" -> null
#       - security_groups     = [
#           - "allow-8000",
#           - "allow-8080",
#           - "allow-8081",
#           - "allow-9001",
#           - "allow-9090",
#           - "allow-http-80",
#           - "allow-ssh",
#         ] -> null
#       - stop_before_destroy = false -> null
#       - tags                = [] -> null
#       - updated             = "2025-04-29 22:25:00 +0000 UTC" -> null
#       - user_data           = "288a94c164b15cc1ff6d8b9f3f2b8806541b5097" -> null
#         # (1 unchanged attribute hidden)
#
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "10.56.3.139" -> null
#           - mac            = "fa:16:3e:11:1c:a0" -> null
#           - name           = "sharednet2" -> null
#           - port           = "ce5fe7a6-e5d4-427f-a4f6-a3acbd47f78c" -> null
#           - uuid           = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#             # (2 unchanged attributes hidden)
#         }
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "192.168.1.13" -> null
#           - mac            = "fa:16:3e:ea:21:02" -> null
#           - name           = "private-net-mlops-jja435" -> null
#           - port           = "2ff4d392-02cd-4b7f-b8c2-5777324cb16e" -> null
#           - uuid           = "63b29d27-ec7d-4470-ba29-2e808e78457b" -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_floatingip_v2.floating_ip will be destroyed
#   - resource "openstack_networking_floatingip_v2" "floating_ip" {
#       - address     = "129.114.25.135" -> null
#       - all_tags    = [] -> null
#       - description = "MLOps IP for jja435" -> null
#       - fixed_ip    = "10.56.0.247" -> null
#       - id          = "b3363574-5d0c-4d9d-b70e-cfb37fd8efef" -> null
#       - pool        = "public" -> null
#       - port_id     = "01ed38ea-8c3d-46ea-b70c-8e63c1d9e859" -> null
#       - region      = "KVM@TACC" -> null
#       - tags        = [] -> null
#       - tenant_id   = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (2 unchanged attributes hidden)
#     }
#
#   # openstack_networking_network_v2.private_net will be destroyed
#   - resource "openstack_networking_network_v2" "private_net" {
#       - admin_state_up          = true -> null
#       - all_tags                = [] -> null
#       - availability_zone_hints = [] -> null
#       - external                = false -> null
#       - id                      = "63b29d27-ec7d-4470-ba29-2e808e78457b" -> null
#       - mtu                     = 1450 -> null
#       - name                    = "private-net-mlops-jja435" -> null
#       - port_security_enabled   = false -> null
#       - region                  = "KVM@TACC" -> null
#       - shared                  = false -> null
#       - tags                    = [] -> null
#       - tenant_id               = "89f528973fea4b3a981f9b2344e522de" -> null
#       - transparent_vlan        = false -> null
#         # (3 unchanged attributes hidden)
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node1"] will be destroyed
#   - resource "openstack_networking_port_v2" "private_net_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "192.168.1.11",
#         ] -> null
#       - all_security_group_ids = [] -> null
#       - all_tags               = [] -> null
#       - device_id              = "be9dfc79-7899-4f34-9150-c615b616d341" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "c32dd38c-7f5d-45db-afdf-320c8df887e2" -> null
#       - mac_address            = "fa:16:3e:8d:e5:74" -> null
#       - name                   = "port-node1-mlops-jja435" -> null
#       - network_id             = "63b29d27-ec7d-4470-ba29-2e808e78457b" -> null
#       - port_security_enabled  = false -> null
#       - region                 = "KVM@TACC" -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#
#       - fixed_ip {
#           - ip_address = "192.168.1.11" -> null
#           - subnet_id  = "93285c03-eb3d-4633-8b5a-8d79235dc24f" -> null
#         }
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node2"] will be destroyed
#   - resource "openstack_networking_port_v2" "private_net_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "192.168.1.12",
#         ] -> null
#       - all_security_group_ids = [] -> null
#       - all_tags               = [] -> null
#       - device_id              = "f4a623fd-f5df-48c7-acf2-018e7cbcf1ad" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "ac46a797-0594-41bb-aae8-60fe6e599fd5" -> null
#       - mac_address            = "fa:16:3e:af:96:10" -> null
#       - name                   = "port-node2-mlops-jja435" -> null
#       - network_id             = "63b29d27-ec7d-4470-ba29-2e808e78457b" -> null
#       - port_security_enabled  = false -> null
#       - region                 = "KVM@TACC" -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#
#       - fixed_ip {
#           - ip_address = "192.168.1.12" -> null
#           - subnet_id  = "93285c03-eb3d-4633-8b5a-8d79235dc24f" -> null
#         }
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node3"] will be destroyed
#   - resource "openstack_networking_port_v2" "private_net_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "192.168.1.13",
#         ] -> null
#       - all_security_group_ids = [] -> null
#       - all_tags               = [] -> null
#       - device_id              = "690a953b-e2f7-46a0-879b-b1bb25128a2d" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "2ff4d392-02cd-4b7f-b8c2-5777324cb16e" -> null
#       - mac_address            = "fa:16:3e:ea:21:02" -> null
#       - name                   = "port-node3-mlops-jja435" -> null
#       - network_id             = "63b29d27-ec7d-4470-ba29-2e808e78457b" -> null
#       - port_security_enabled  = false -> null
#       - region                 = "KVM@TACC" -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#
#       - fixed_ip {
#           - ip_address = "192.168.1.13" -> null
#           - subnet_id  = "93285c03-eb3d-4633-8b5a-8d79235dc24f" -> null
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node1"] will be destroyed
#   - resource "openstack_networking_port_v2" "sharednet2_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "10.56.0.247",
#         ] -> null
#       - all_security_group_ids = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "be9dfc79-7899-4f34-9150-c615b616d341" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "01ed38ea-8c3d-46ea-b70c-8e63c1d9e859" -> null
#       - mac_address            = "fa:16:3e:5b:dd:f7" -> null
#       - name                   = "sharednet2-node1-mlops-jja435" -> null
#       - network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - security_group_ids     = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node2"] will be destroyed
#   - resource "openstack_networking_port_v2" "sharednet2_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "10.56.0.223",
#         ] -> null
#       - all_security_group_ids = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "f4a623fd-f5df-48c7-acf2-018e7cbcf1ad" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "00ea009a-2581-435b-beab-db441abc7f8c" -> null
#       - mac_address            = "fa:16:3e:e4:74:9b" -> null
#       - name                   = "sharednet2-node2-mlops-jja435" -> null
#       - network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - security_group_ids     = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node3"] will be destroyed
#   - resource "openstack_networking_port_v2" "sharednet2_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "10.56.3.139",
#         ] -> null
#       - all_security_group_ids = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "690a953b-e2f7-46a0-879b-b1bb25128a2d" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "ce5fe7a6-e5d4-427f-a4f6-a3acbd47f78c" -> null
#       - mac_address            = "fa:16:3e:11:1c:a0" -> null
#       - name                   = "sharednet2-node3-mlops-jja435" -> null
#       - network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - security_group_ids     = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_subnet_v2.private_subnet will be destroyed
#   - resource "openstack_networking_subnet_v2" "private_subnet" {
#       - all_tags          = [] -> null
#       - cidr              = "192.168.1.0/24" -> null
#       - dns_nameservers   = [] -> null
#       - enable_dhcp       = true -> null
#       - id                = "93285c03-eb3d-4633-8b5a-8d79235dc24f" -> null
#       - ip_version        = 4 -> null
#       - name              = "private-subnet-mlops-jja435" -> null
#       - network_id        = "63b29d27-ec7d-4470-ba29-2e808e78457b" -> null
#       - no_gateway        = true -> null
#       - region            = "KVM@TACC" -> null
#       - service_types     = [] -> null
#       - tags              = [] -> null
#       - tenant_id         = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (5 unchanged attributes hidden)
#
#       - allocation_pool {
#           - end   = "192.168.1.254" -> null
#           - start = "192.168.1.1" -> null
#         }
#
#       - allocation_pools {
#           - end   = "192.168.1.254" -> null
#           - start = "192.168.1.1" -> null
#         }
#     }
#
# Plan: 0 to add, 0 to change, 12 to destroy.
#
# Changes to Outputs:
#   - floating_ip_out = "129.114.25.135" -> null
# openstack_networking_floatingip_v2.floating_ip: Destroying... [id=b3363574-5d0c-4d9d-b70e-cfb37fd8efef]
# openstack_compute_instance_v2.nodes["node3"]: Destroying... [id=690a953b-e2f7-46a0-879b-b1bb25128a2d]
# openstack_compute_instance_v2.nodes["node2"]: Destroying... [id=f4a623fd-f5df-48c7-acf2-018e7cbcf1ad]
# openstack_compute_instance_v2.nodes["node1"]: Destroying... [id=be9dfc79-7899-4f34-9150-c615b616d341]
# openstack_networking_floatingip_v2.floating_ip: Destruction complete after 6s
# openstack_compute_instance_v2.nodes["node3"]: Still destroying... [id=690a953b-e2f7-46a0-879b-b1bb25128a2d, 10s elapsed]
# openstack_compute_instance_v2.nodes["node2"]: Still destroying... [id=f4a623fd-f5df-48c7-acf2-018e7cbcf1ad, 10s elapsed]
# openstack_compute_instance_v2.nodes["node1"]: Still destroying... [id=be9dfc79-7899-4f34-9150-c615b616d341, 10s elapsed]
# openstack_compute_instance_v2.nodes["node3"]: Destruction complete after 11s
# openstack_compute_instance_v2.nodes["node1"]: Destruction complete after 11s
# openstack_compute_instance_v2.nodes["node2"]: Destruction complete after 11s
# openstack_networking_port_v2.private_net_ports["node1"]: Destroying... [id=c32dd38c-7f5d-45db-afdf-320c8df887e2]
# openstack_networking_port_v2.private_net_ports["node2"]: Destroying... [id=ac46a797-0594-41bb-aae8-60fe6e599fd5]
# openstack_networking_port_v2.sharednet2_ports["node2"]: Destroying... [id=00ea009a-2581-435b-beab-db441abc7f8c]
# openstack_networking_port_v2.sharednet2_ports["node1"]: Destroying... [id=01ed38ea-8c3d-46ea-b70c-8e63c1d9e859]
# openstack_networking_port_v2.private_net_ports["node3"]: Destroying... [id=2ff4d392-02cd-4b7f-b8c2-5777324cb16e]
# openstack_networking_port_v2.sharednet2_ports["node3"]: Destroying... [id=ce5fe7a6-e5d4-427f-a4f6-a3acbd47f78c]
# openstack_networking_port_v2.private_net_ports["node1"]: Destruction complete after 5s
# openstack_networking_port_v2.sharednet2_ports["node1"]: Destruction complete after 5s
# openstack_networking_port_v2.sharednet2_ports["node3"]: Destruction complete after 5s
# openstack_networking_port_v2.private_net_ports["node3"]: Destruction complete after 5s
# openstack_networking_port_v2.private_net_ports["node2"]: Destruction complete after 5s
# openstack_networking_subnet_v2.private_subnet: Destroying... [id=93285c03-eb3d-4633-8b5a-8d79235dc24f]
# openstack_networking_port_v2.sharednet2_ports["node2"]: Destruction complete after 6s
# openstack_networking_subnet_v2.private_subnet: Destruction complete after 9s
# openstack_networking_network_v2.private_net: Destroying... [id=63b29d27-ec7d-4470-ba29-2e808e78457b]
# openstack_networking_network_v2.private_net: Destruction complete after 5s
#
# Destroy complete! Resources: 12 destroyed.
