# %% [markdown]
# ## Delete infrastructure with Terraform
#
# Since we provisioned our infrastructure with Terraform, we can also delete all the associated resources using Terraform.

# %%
# runs in Chameleon Jupyter environment
cd /work/NYC-Vision-Zero-MLOPS/tf/kvm

# %%
# runs in Chameleon Jupyter environment
export PATH=/work/.local/bin:$PATH

# %%
# runs in Chameleon Jupyter environment
unset $(set | grep -o "^OS_[A-Za-z0-9_]*")

# %% [markdown]
# In the following cell, **replace `netID` with your actual net ID, and replace `id_rsa_chameleon` with the name of *your* personal key that you use to access Chameleon resources**.

# %%
# runs in Chameleon Jupyter environment
export TF_VAR_suffix=project1
export TF_VAR_key=nyc-vision-zero

# %%
# runs in Chameleon Jupyter environment
terraform destroy -auto-approve
# Out:
# data.openstack_networking_secgroup_v2.allow_8081: Reading...
# data.openstack_networking_secgroup_v2.allow_8000: Reading...
# data.openstack_networking_secgroup_v2.allow_9001: Reading...
# data.openstack_networking_secgroup_v2.allow_9090: Reading...
# data.openstack_networking_secgroup_v2.allow_ssh: Reading...
# data.openstack_networking_subnet_v2.sharednet2_subnet: Reading...
# data.openstack_networking_secgroup_v2.allow_8080: Reading...
# data.openstack_networking_network_v2.sharednet2: Reading...
# data.openstack_networking_secgroup_v2.allow_http_80: Reading...
# openstack_networking_network_v2.private_net: Refreshing state... [id=0f993098-bad1-4bb8-81ab-6812c4ac7a9a]
# data.openstack_networking_secgroup_v2.allow_9090: Read complete after 1s [id=d6736d54-d9a4-431c-a5b5-4d29dbcdee03]
# data.openstack_networking_secgroup_v2.allow_9001: Read complete after 1s [id=ad2912c0-caa9-49e0-b431-b9b3953b91b3]
# data.openstack_networking_secgroup_v2.allow_ssh: Read complete after 1s [id=47860acf-9269-4d26-84b1-363824f7e0a2]
# data.openstack_networking_subnet_v2.sharednet2_subnet: Read complete after 1s [id=00b8d316-7617-4da4-b6c0-b7dd1dd78cd4]
# data.openstack_networking_secgroup_v2.allow_8000: Read complete after 1s [id=17a6d962-cc23-4551-ac0b-08b098f451d2]
# data.openstack_networking_secgroup_v2.allow_8080: Read complete after 1s [id=e6eff5db-c96d-4e3d-be49-1ade281f4a7a]
# data.openstack_networking_secgroup_v2.allow_8081: Read complete after 1s [id=9806d71f-f0bd-4c5d-8c48-f32db3094575]
# data.openstack_networking_secgroup_v2.allow_http_80: Read complete after 1s [id=5df2db36-79f9-4b9b-b6c9-1ece762d83fb]
# data.openstack_networking_network_v2.sharednet2: Read complete after 1s [id=4ec616b2-79e1-4813-abca-f2ceb41e0a89]
# openstack_networking_port_v2.sharednet2_ports["node3"]: Refreshing state... [id=29af4146-19aa-4005-affc-f6cbef0eaf8b]
# openstack_networking_port_v2.sharednet2_ports["node2"]: Refreshing state... [id=e698023f-c584-40bf-bc8b-532096f045e6]
# openstack_networking_port_v2.sharednet2_ports["node1"]: Refreshing state... [id=7db1622e-d8f9-435c-b3b1-f99e49f04ecf]
# openstack_networking_subnet_v2.private_subnet: Refreshing state... [id=1842377f-1655-43f9-a985-d586f58c0c49]
# openstack_networking_port_v2.private_net_ports["node2"]: Refreshing state... [id=1617eab1-a3a8-424f-af91-405b26fe861e]
# openstack_networking_port_v2.private_net_ports["node1"]: Refreshing state... [id=e9e7e9a3-fc76-4d2d-a741-c3fb9d96df48]
# openstack_networking_port_v2.private_net_ports["node3"]: Refreshing state... [id=645a704b-3eed-4b94-86aa-1cb476f4495d]
# openstack_networking_floatingip_v2.floating_ip: Refreshing state... [id=0caaa8c7-1631-4c73-9812-7b1e9b84b69f]
# openstack_compute_instance_v2.nodes["node2"]: Refreshing state... [id=6ffdc181-91ea-49af-aa65-80879f507f03]
# openstack_compute_instance_v2.nodes["node1"]: Refreshing state... [id=af55cddb-fed8-40c2-b3da-242459a4a712]
# openstack_compute_instance_v2.nodes["node3"]: Refreshing state... [id=756fcf9b-7b99-46ce-8c4c-992e02c8329e]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # openstack_compute_instance_v2.nodes["node1"] will be destroyed
#   - resource "openstack_compute_instance_v2" "nodes" {
#       - access_ip_v4        = "10.56.3.23" -> null
#       - all_metadata        = {} -> null
#       - all_tags            = [] -> null
#       - availability_zone   = "nova" -> null
#       - created             = "2025-05-05 21:29:42 +0000 UTC" -> null
#       - flavor_id           = "3" -> null
#       - flavor_name         = "m1.medium" -> null
#       - force_delete        = false -> null
#       - id                  = "af55cddb-fed8-40c2-b3da-242459a4a712" -> null
#       - image_id            = "96d9c658-6540-4796-ae64-54d8ac6c45f8" -> null
#       - image_name          = "CC-Ubuntu24.04" -> null
#       - key_pair            = "nyc_vision_zero" -> null
#       - name                = "node1-mlops-project1" -> null
#       - power_state         = "active" -> null
#       - region              = "KVM@TACC" -> null
#       - security_groups     = [
#           - "allow-8000",
#           - "allow-8080",
#           - "allow-8081",
#           - "allow-9001",
#           - "allow-9090",
#           - "allow-http-80",
#           - "allow-ssh",
#         ] -> null
#       - stop_before_destroy = false -> null
#       - tags                = [] -> null
#       - updated             = "2025-05-05 21:29:49 +0000 UTC" -> null
#       - user_data           = "639552184e391c8680697a3c6f52983c926192ce" -> null
#         # (1 unchanged attribute hidden)
#
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "10.56.3.23" -> null
#           - mac            = "fa:16:3e:6b:89:d8" -> null
#           - name           = "sharednet2" -> null
#           - port           = "7db1622e-d8f9-435c-b3b1-f99e49f04ecf" -> null
#           - uuid           = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#             # (2 unchanged attributes hidden)
#         }
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "192.168.1.11" -> null
#           - mac            = "fa:16:3e:f7:cb:0d" -> null
#           - name           = "private-net-mlops-project1" -> null
#           - port           = "e9e7e9a3-fc76-4d2d-a741-c3fb9d96df48" -> null
#           - uuid           = "0f993098-bad1-4bb8-81ab-6812c4ac7a9a" -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_compute_instance_v2.nodes["node2"] will be destroyed
#   - resource "openstack_compute_instance_v2" "nodes" {
#       - access_ip_v4        = "10.56.1.42" -> null
#       - all_metadata        = {} -> null
#       - all_tags            = [] -> null
#       - availability_zone   = "nova" -> null
#       - created             = "2025-05-05 21:29:42 +0000 UTC" -> null
#       - flavor_id           = "3" -> null
#       - flavor_name         = "m1.medium" -> null
#       - force_delete        = false -> null
#       - id                  = "6ffdc181-91ea-49af-aa65-80879f507f03" -> null
#       - image_id            = "96d9c658-6540-4796-ae64-54d8ac6c45f8" -> null
#       - image_name          = "CC-Ubuntu24.04" -> null
#       - key_pair            = "nyc_vision_zero" -> null
#       - name                = "node2-mlops-project1" -> null
#       - power_state         = "active" -> null
#       - region              = "KVM@TACC" -> null
#       - security_groups     = [
#           - "allow-8000",
#           - "allow-8080",
#           - "allow-8081",
#           - "allow-9001",
#           - "allow-9090",
#           - "allow-http-80",
#           - "allow-ssh",
#         ] -> null
#       - stop_before_destroy = false -> null
#       - tags                = [] -> null
#       - updated             = "2025-05-05 21:29:49 +0000 UTC" -> null
#       - user_data           = "00a785b714e15a8813ae42174196bfe696d4b0e9" -> null
#         # (1 unchanged attribute hidden)
#
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "10.56.1.42" -> null
#           - mac            = "fa:16:3e:90:b3:8a" -> null
#           - name           = "sharednet2" -> null
#           - port           = "e698023f-c584-40bf-bc8b-532096f045e6" -> null
#           - uuid           = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#             # (2 unchanged attributes hidden)
#         }
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "192.168.1.12" -> null
#           - mac            = "fa:16:3e:fc:f1:1d" -> null
#           - name           = "private-net-mlops-project1" -> null
#           - port           = "1617eab1-a3a8-424f-af91-405b26fe861e" -> null
#           - uuid           = "0f993098-bad1-4bb8-81ab-6812c4ac7a9a" -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_compute_instance_v2.nodes["node3"] will be destroyed
#   - resource "openstack_compute_instance_v2" "nodes" {
#       - access_ip_v4        = "10.56.3.6" -> null
#       - all_metadata        = {} -> null
#       - all_tags            = [] -> null
#       - availability_zone   = "nova" -> null
#       - created             = "2025-05-05 21:29:42 +0000 UTC" -> null
#       - flavor_id           = "3" -> null
#       - flavor_name         = "m1.medium" -> null
#       - force_delete        = false -> null
#       - id                  = "756fcf9b-7b99-46ce-8c4c-992e02c8329e" -> null
#       - image_id            = "96d9c658-6540-4796-ae64-54d8ac6c45f8" -> null
#       - image_name          = "CC-Ubuntu24.04" -> null
#       - key_pair            = "nyc_vision_zero" -> null
#       - name                = "node3-mlops-project1" -> null
#       - power_state         = "active" -> null
#       - region              = "KVM@TACC" -> null
#       - security_groups     = [
#           - "allow-8000",
#           - "allow-8080",
#           - "allow-8081",
#           - "allow-9001",
#           - "allow-9090",
#           - "allow-http-80",
#           - "allow-ssh",
#         ] -> null
#       - stop_before_destroy = false -> null
#       - tags                = [] -> null
#       - updated             = "2025-05-05 21:29:51 +0000 UTC" -> null
#       - user_data           = "9680a4d2c8216dd2176923aa822dffd64b4ddcca" -> null
#         # (1 unchanged attribute hidden)
#
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "10.56.3.6" -> null
#           - mac            = "fa:16:3e:bb:c8:cc" -> null
#           - name           = "sharednet2" -> null
#           - port           = "29af4146-19aa-4005-affc-f6cbef0eaf8b" -> null
#           - uuid           = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#             # (2 unchanged attributes hidden)
#         }
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "192.168.1.13" -> null
#           - mac            = "fa:16:3e:f7:ad:cc" -> null
#           - name           = "private-net-mlops-project1" -> null
#           - port           = "645a704b-3eed-4b94-86aa-1cb476f4495d" -> null
#           - uuid           = "0f993098-bad1-4bb8-81ab-6812c4ac7a9a" -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_floatingip_v2.floating_ip will be destroyed
#   - resource "openstack_networking_floatingip_v2" "floating_ip" {
#       - address     = "129.114.26.23" -> null
#       - all_tags    = [] -> null
#       - description = "MLOps IP for project1" -> null
#       - fixed_ip    = "10.56.3.23" -> null
#       - id          = "0caaa8c7-1631-4c73-9812-7b1e9b84b69f" -> null
#       - pool        = "public" -> null
#       - port_id     = "7db1622e-d8f9-435c-b3b1-f99e49f04ecf" -> null
#       - region      = "KVM@TACC" -> null
#       - tags        = [] -> null
#       - tenant_id   = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (2 unchanged attributes hidden)
#     }
#
#   # openstack_networking_network_v2.private_net will be destroyed
#   - resource "openstack_networking_network_v2" "private_net" {
#       - admin_state_up          = true -> null
#       - all_tags                = [] -> null
#       - availability_zone_hints = [] -> null
#       - external                = false -> null
#       - id                      = "0f993098-bad1-4bb8-81ab-6812c4ac7a9a" -> null
#       - mtu                     = 1450 -> null
#       - name                    = "private-net-mlops-project1" -> null
#       - port_security_enabled   = false -> null
#       - region                  = "KVM@TACC" -> null
#       - shared                  = false -> null
#       - tags                    = [] -> null
#       - tenant_id               = "89f528973fea4b3a981f9b2344e522de" -> null
#       - transparent_vlan        = false -> null
#         # (3 unchanged attributes hidden)
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node1"] will be destroyed
#   - resource "openstack_networking_port_v2" "private_net_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "192.168.1.11",
#         ] -> null
#       - all_security_group_ids = [] -> null
#       - all_tags               = [] -> null
#       - device_id              = "af55cddb-fed8-40c2-b3da-242459a4a712" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "e9e7e9a3-fc76-4d2d-a741-c3fb9d96df48" -> null
#       - mac_address            = "fa:16:3e:f7:cb:0d" -> null
#       - name                   = "port-node1-mlops-project1" -> null
#       - network_id             = "0f993098-bad1-4bb8-81ab-6812c4ac7a9a" -> null
#       - port_security_enabled  = false -> null
#       - region                 = "KVM@TACC" -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#
#       - fixed_ip {
#           - ip_address = "192.168.1.11" -> null
#           - subnet_id  = "1842377f-1655-43f9-a985-d586f58c0c49" -> null
#         }
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node2"] will be destroyed
#   - resource "openstack_networking_port_v2" "private_net_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "192.168.1.12",
#         ] -> null
#       - all_security_group_ids = [] -> null
#       - all_tags               = [] -> null
#       - device_id              = "6ffdc181-91ea-49af-aa65-80879f507f03" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "1617eab1-a3a8-424f-af91-405b26fe861e" -> null
#       - mac_address            = "fa:16:3e:fc:f1:1d" -> null
#       - name                   = "port-node2-mlops-project1" -> null
#       - network_id             = "0f993098-bad1-4bb8-81ab-6812c4ac7a9a" -> null
#       - port_security_enabled  = false -> null
#       - region                 = "KVM@TACC" -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#
#       - fixed_ip {
#           - ip_address = "192.168.1.12" -> null
#           - subnet_id  = "1842377f-1655-43f9-a985-d586f58c0c49" -> null
#         }
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node3"] will be destroyed
#   - resource "openstack_networking_port_v2" "private_net_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "192.168.1.13",
#         ] -> null
#       - all_security_group_ids = [] -> null
#       - all_tags               = [] -> null
#       - device_id              = "756fcf9b-7b99-46ce-8c4c-992e02c8329e" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "645a704b-3eed-4b94-86aa-1cb476f4495d" -> null
#       - mac_address            = "fa:16:3e:f7:ad:cc" -> null
#       - name                   = "port-node3-mlops-project1" -> null
#       - network_id             = "0f993098-bad1-4bb8-81ab-6812c4ac7a9a" -> null
#       - port_security_enabled  = false -> null
#       - region                 = "KVM@TACC" -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#
#       - fixed_ip {
#           - ip_address = "192.168.1.13" -> null
#           - subnet_id  = "1842377f-1655-43f9-a985-d586f58c0c49" -> null
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node1"] will be destroyed
#   - resource "openstack_networking_port_v2" "sharednet2_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "10.56.3.23",
#         ] -> null
#       - all_security_group_ids = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "af55cddb-fed8-40c2-b3da-242459a4a712" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "7db1622e-d8f9-435c-b3b1-f99e49f04ecf" -> null
#       - mac_address            = "fa:16:3e:6b:89:d8" -> null
#       - name                   = "sharednet2-node1-mlops-project1" -> null
#       - network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - security_group_ids     = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node2"] will be destroyed
#   - resource "openstack_networking_port_v2" "sharednet2_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "10.56.1.42",
#         ] -> null
#       - all_security_group_ids = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "6ffdc181-91ea-49af-aa65-80879f507f03" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "e698023f-c584-40bf-bc8b-532096f045e6" -> null
#       - mac_address            = "fa:16:3e:90:b3:8a" -> null
#       - name                   = "sharednet2-node2-mlops-project1" -> null
#       - network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - security_group_ids     = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node3"] will be destroyed
#   - resource "openstack_networking_port_v2" "sharednet2_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "10.56.3.6",
#         ] -> null
#       - all_security_group_ids = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "756fcf9b-7b99-46ce-8c4c-992e02c8329e" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "29af4146-19aa-4005-affc-f6cbef0eaf8b" -> null
#       - mac_address            = "fa:16:3e:bb:c8:cc" -> null
#       - name                   = "sharednet2-node3-mlops-project1" -> null
#       - network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - security_group_ids     = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_subnet_v2.private_subnet will be destroyed
#   - resource "openstack_networking_subnet_v2" "private_subnet" {
#       - all_tags          = [] -> null
#       - cidr              = "192.168.1.0/24" -> null
#       - dns_nameservers   = [] -> null
#       - enable_dhcp       = true -> null
#       - id                = "1842377f-1655-43f9-a985-d586f58c0c49" -> null
#       - ip_version        = 4 -> null
#       - name              = "private-subnet-mlops-project1" -> null
#       - network_id        = "0f993098-bad1-4bb8-81ab-6812c4ac7a9a" -> null
#       - no_gateway        = true -> null
#       - region            = "KVM@TACC" -> null
#       - service_types     = [] -> null
#       - tags              = [] -> null
#       - tenant_id         = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (5 unchanged attributes hidden)
#
#       - allocation_pool {
#           - end   = "192.168.1.254" -> null
#           - start = "192.168.1.1" -> null
#         }
#
#       - allocation_pools {
#           - end   = "192.168.1.254" -> null
#           - start = "192.168.1.1" -> null
#         }
#     }
#
# Plan: 0 to add, 0 to change, 12 to destroy.
#
# Changes to Outputs:
#   - floating_ip_out = "129.114.26.23" -> null
# openstack_networking_floatingip_v2.floating_ip: Destroying... [id=0caaa8c7-1631-4c73-9812-7b1e9b84b69f]
# openstack_compute_instance_v2.nodes["node2"]: Destroying... [id=6ffdc181-91ea-49af-aa65-80879f507f03]
# openstack_compute_instance_v2.nodes["node1"]: Destroying... [id=af55cddb-fed8-40c2-b3da-242459a4a712]
# openstack_compute_instance_v2.nodes["node3"]: Destroying... [id=756fcf9b-7b99-46ce-8c4c-992e02c8329e]
# openstack_networking_floatingip_v2.floating_ip: Destruction complete after 7s
# openstack_compute_instance_v2.nodes["node2"]: Still destroying... [id=6ffdc181-91ea-49af-aa65-80879f507f03, 10s elapsed]
# openstack_compute_instance_v2.nodes["node1"]: Still destroying... [id=af55cddb-fed8-40c2-b3da-242459a4a712, 10s elapsed]
# openstack_compute_instance_v2.nodes["node3"]: Still destroying... [id=756fcf9b-7b99-46ce-8c4c-992e02c8329e, 10s elapsed]
# openstack_compute_instance_v2.nodes["node2"]: Destruction complete after 11s
# openstack_compute_instance_v2.nodes["node3"]: Destruction complete after 11s
# openstack_compute_instance_v2.nodes["node1"]: Destruction complete after 11s
# openstack_networking_port_v2.sharednet2_ports["node2"]: Destroying... [id=e698023f-c584-40bf-bc8b-532096f045e6]
# openstack_networking_port_v2.private_net_ports["node3"]: Destroying... [id=645a704b-3eed-4b94-86aa-1cb476f4495d]
# openstack_networking_port_v2.private_net_ports["node1"]: Destroying... [id=e9e7e9a3-fc76-4d2d-a741-c3fb9d96df48]
# openstack_networking_port_v2.private_net_ports["node2"]: Destroying... [id=1617eab1-a3a8-424f-af91-405b26fe861e]
# openstack_networking_port_v2.sharednet2_ports["node1"]: Destroying... [id=7db1622e-d8f9-435c-b3b1-f99e49f04ecf]
# openstack_networking_port_v2.sharednet2_ports["node3"]: Destroying... [id=29af4146-19aa-4005-affc-f6cbef0eaf8b]
# openstack_networking_port_v2.private_net_ports["node3"]: Destruction complete after 6s
# openstack_networking_port_v2.private_net_ports["node2"]: Destruction complete after 6s
# openstack_networking_port_v2.private_net_ports["node1"]: Destruction complete after 6s
# openstack_networking_subnet_v2.private_subnet: Destroying... [id=1842377f-1655-43f9-a985-d586f58c0c49]
# openstack_networking_port_v2.sharednet2_ports["node2"]: Destruction complete after 7s
# openstack_networking_port_v2.sharednet2_ports["node3"]: Destruction complete after 7s
# openstack_networking_port_v2.sharednet2_ports["node1"]: Destruction complete after 9s
# openstack_networking_subnet_v2.private_subnet: Destruction complete after 8s
# openstack_networking_network_v2.private_net: Destroying... [id=0f993098-bad1-4bb8-81ab-6812c4ac7a9a]
# openstack_networking_network_v2.private_net: Destruction complete after 6s
#
# Destroy complete! Resources: 12 destroyed.
